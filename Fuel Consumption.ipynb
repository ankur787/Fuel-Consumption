# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\ankur\\Desktop\\17 - Fuel Consumption Project (Decision Tree and Random Forests in R)'

# %%
fuel= pd.read_csv('HyundaiCreta.csv')

# %%
fuel
# Out:
#             date   time         Received       Lat       Lon  Speed  Heading  \
# 0      5/26/2016   6:15   5/26/2016 6:15  12.82556  80.21642      0      132
# 1      5/26/2016   6:00   5/26/2016 6:00  12.82556  80.21642      0      132
# 2      5/26/2016   5:45   5/26/2016 5:45  12.82556  80.21642      0      132
# 3      5/26/2016   5:30   5/26/2016 5:30  12.82556  80.21642      0      132
# 4      5/26/2016   5:15   5/26/2016 5:15  12.82556  80.21642      0      132
# 5      5/26/2016   5:15   5/26/2016 5:15  12.82556  80.21642      0      132
# 6      5/26/2016   5:14   5/26/2016 5:14  12.82556  80.21642      0      132
# 7      5/26/2016   5:14   5/26/2016 5:14  12.82556  80.21642      0      132
# 8      5/26/2016   5:13   5/26/2016 5:13  12.82556  80.21642     20      132
# 9      5/26/2016   5:13   5/26/2016 5:13  12.82558  80.21639     16      128
# 10     5/26/2016   5:13   5/26/2016 5:13  12.82560  80.21638     16      115
# ...

# %%
fuel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41320 entries, 0 to 41319
# Data columns (total 72 columns):
# date                   41320 non-null object
# time                   41297 non-null object
# Received               41320 non-null object
# Lat                    41320 non-null float64
# Lon                    41320 non-null float64
# Speed                  41320 non-null int64
# Heading                41320 non-null int64
# Altitude               41320 non-null int64
# Accuracy               41320 non-null int64
# Address                41295 non-null object
# Parts                  3852 non-null float64
# Seq                    41320 non-null int64
# Acc_pos                41320 non-null int64
# Acc_speed              41320 non-null int64
# Power_disconnect       41320 non-null int64
# Ignition               41320 non-null int64
# Digital_01             41320 non-null int64
# Output_01              41320 non-null int64
# Battery_voltage        41320 non-null float64
# ...

# %%
len(fuel)
# Out:
# 41320

# %%
fuel.shape
# Out:
# (41320, 72)
